# %% [markdown]
# # Heart Disease Prediction using K-Nearest Neighbors
#
# ## Model Training and Evaluation
#
# This notebook trains a K-Nearest Neighbors (KNN) classifier on the processed Cleveland Heart Disease dataset and evaluates its performance using multiple classification metrics.

# %% [markdown]
# ## Step 55: Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# %% [markdown]
# ## Step 56: Load the dataset

# %%
columns = [
    "age",
    "sex",
    "cp",
    "trestbps",
    "chol",
    "fbs",
    "restecg",
    "thalach",
    "exang",
    "oldpeak",
    "slope",
    "ca",
    "thal",
    "target"
]

df = pd.read_csv(
    "../data/heart.csv",
    header=None,
    names=columns
)

df.head()

# %% [markdown]
# ## Step 57: Handle missing values

# %%
# Replace '?' with NaN
df.replace("?", np.nan, inplace=True)

# Convert columns to numeric
df["ca"] = pd.to_numeric(df["ca"])
df["thal"] = pd.to_numeric(df["thal"])

# Fill missing values with the median
df.fillna(df.median(numeric_only=True), inplace=True)

# Verify
df.isnull().sum()

# %% [markdown]
# ## Step 58: Convert the target variable to binary

# %%
df["target"] = df["target"].apply(lambda x: 0 if x == 0 else 1)

df["target"].value_counts()

# %% [markdown]
# ## Step 59: Separate features and target

# %%
X = df.drop("target", axis=1)
y = df["target"]

print(X.shape)
print(y.shape)

# %% [markdown]
# ## Step 60: Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", X_train.shape[0])
print("Testing samples :", X_test.shape[0])

# %% [markdown]
# ## Step 61: Scale the features

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Train the K-Nearest Neighbors (KNN) Model
#
# We begin with **K = 5**, a commonly used default value. Later, we'll tune this hyperparameter to determine the optimal number of neighbors.

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %% [markdown]
# ## Step 63: Train the Model

# %%
knn.fit(X_train_scaled, y_train)

# %% [markdown]
# ## Step 64: Make Predictions

# %%
y_pred = knn.predict(X_test_scaled)

y_pred[:10]

# %% [markdown]
# ## Model Accuracy
#
# Accuracy measures the percentage of correctly classified patients.

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy : {accuracy:.4f}")
print(f"Accuracy : {accuracy:.2%}")

# %% [markdown]
# ## Precision
#
# Precision answers the question:
#
# > Of all patients predicted to have heart disease, how many actually had heart disease?

# %%
precision = precision_score(y_test, y_pred)

print(f"Precision : {precision:.4f}")
print(f"Precision : {precision:.2%}")

# %% [markdown]
# ## Recall (Sensitivity)
#
# Recall is especially important in healthcare because it measures how many actual heart disease cases were correctly identified.

# %%
recall = recall_score(y_test, y_pred)

print(f"Recall : {recall:.4f}")
print(f"Recall : {recall:.2%}")

# %% [markdown]
# ## F1-Score
#
# F1-score balances precision and recall, making it useful when both false positives and false negatives matter.

# %%
f1 = f1_score(y_test, y_pred)

print(f"F1 Score : {f1:.4f}")
print(f"F1 Score : {f1:.2%}")

# %% [markdown]
# ## Classification Report
#
# The classification report summarizes precision, recall, F1-score, and support for each class.

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## Confusion Matrix
#
# The confusion matrix shows:
#
# - True Positives (TP)
# - True Negatives (TN)
# - False Positives (FP)
# - False Negatives (FN)

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["No Disease", "Disease"]
)

disp.plot(cmap="Blues")

plt.title("Confusion Matrix - KNN")

plt.savefig(
    "../reports/figures/confusion_matrix_knn.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Specificity
#
# Specificity measures how well the model correctly identifies patients **without** heart disease.

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

specificity = tn / (tn + fp)

print(f"Specificity : {specificity:.4f}")
print(f"Specificity : {specificity:.2%}")

# %% [markdown]
# ## Initial Model Evaluation
#
# The initial KNN classifier provides a baseline for predicting heart disease.
#
# While the model achieves good overall performance, the choice of **K = 5** is arbitrary. In the next phase, we will tune the value of **K** to determine whether performance can be improved, particularly with respect to **recall (sensitivity)**, which is critical in healthcare applications.
