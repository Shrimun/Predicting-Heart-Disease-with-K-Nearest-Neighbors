# %% [markdown]
# # Heart Disease Prediction using K-Nearest Neighbors
#
# ## Model Training and Evaluation
#
# This notebook trains a K-Nearest Neighbors (KNN) classifier on the processed Cleveland Heart Disease dataset and evaluates its performance using multiple classification metrics.
